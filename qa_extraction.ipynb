# %% [markdown]
# ## Question & Answer Pair Extraction
# In this notebook, I extract the test questions and their corresponding answers from the corpus by first running a question generation model on the corpus, and then manually editing, answering and ranking the questions.

# %%
# !pip install transformers llama-index protobuf SentencePiece llama-index-readers-pdf-table
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)

# %% [markdown]
# ### Load in the data using Simple Directory Reader

# %%
from llama_index.core import SimpleDirectoryReader

# loading in data
reader = SimpleDirectoryReader(input_dir='data')
data = reader.load_data()

# %% [markdown]
# Extract from document object and put the contents of each page in a list, clean up with regex

# %%
import regex as re

input_text = []
for i in range(16,184):
    page = data[i].text
    page = re.sub(r'\s+', ' ', page)
    input_text.append(page)

# %% [markdown]
# ### Question generation part
# Import the question generation model and run it on the input text. We divide each page into five and generate a question from each part; resulting in 5 questions per page.

# %%
from transformers import T5Config, T5ForConditionalGeneration, T5Tokenizer

model_name = "allenai/t5-small-squad2-question-generation"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)

def run_model(input_string, **generator_args):
    input_ids = tokenizer.encode(input_string, return_tensors="pt")
    res = model.generate(input_ids, **generator_args)
    output = tokenizer.batch_decode(res, skip_special_tokens=True)
    print(output)
    return output


all_questions = []

for i in range(len(input_text)):
  n_parts = 5
  length = len(input_text[i])
  page_text = input_text[i]
  part_size = length // n_parts  # Approximate size of each part

  # Create slices
  parts = [page_text[j:j+part_size] for j in range(0, length, part_size)]

  # Ensure exactly 5 parts (combine excess characters into the last part)
  if len(parts) > n_parts:
      parts = parts[:n_parts-1] + [''.join(parts[n_parts-1:])]

  page_questions = [run_model(part) for part in parts]
  all_questions.append(page_questions)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.86k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# pytorch_model.bin:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1375: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ['What is the annual WASHNORM survey?']
# ['What was the first WASHNORM conducted in 2018?']
# ['What was the second edition of the WASHNORM survey conducted between August 2019 and February 2020']
# ['What was added to the household module on COVID 19?']
# ['What is the basis for a systematic monitoring of prog ress towards attainment of key']
# ['What is the basis for developing state-wide WASH investment plans?']
# ['What is the name of the survey report presented in?']
# ['What is the detailed methodology of the WASHNORM 2021 survey?']
# ['What was the data collection conducted in the third and fourth quarter of 2021?']
# ['How many EAs were covered in the NISH sampling frame?']
# ['How many households were canvassed in each of the 34 states and FCT?']
# ['What was the name of the sampling frames developed?']
# ['How many primary and secondary schools were listed across the country?']
# ['How many households were covered out of the targeted 7,400?']
# ['What is the actual number of samples assessed for the 2021 WASHNORM?']
# ['What is the name of the survey that WASHNORM uses?']
# ['What was the purpose of a questionnaire developed specifically for the urban water utilities?']
# ['What was the water facilities mapping module covered?']
# ['What was the name of the water utilities network mapping tool?']
# ['How many WASH in Educational Facilities Schools?']
# ['What was the purpose of the pre-test and pilot test of the survey?']
# ['What is the purpose of the WASHNORM survey?']
# ['How many coordinators did the survey collect?']
# ['What was the main survey of the FMWR?']
# ['What was the tolerant coliform observed in the ho usehold water at the point of']
# ['How many state water utilities were studied for mapping their waterworks?']
# ['What was the overall response rate for the 2021 WASHNORM household survey?']
# ['What was the purpose of data quality control?']
# ['What was the purpose of the WASHNORM?']
# ['What is the average value of WASH in the report?']
# ['How many people in Nigeria live with disabilities?']
# ['How many households lived in rural areas?']
# ['How many households reported suffering from diarrh oea in the past two weeks']
# ['How much is access to basic water supply services available to the richest households?']
# ['How many households use pipe-borne water?']
# ['How many households have access to improved water supply within the premises?']
# ['How many people are found to have access to basic sanitation services in 2021?']
# ['How many people use safe managed sanitations services?']
# ['How many households were reported to have knowledge of at least two critical times for handwashing?']
# ['How many states have urban water utilities?']
# ['How many waterworks are there in Nigeria?']
# ['How many cubic metres of water per day were waterworks assessed?']
# ['How many households are satisfied with water supplied?']
# ['How many water points are in Nigeria?']
# ['How many water points are publicly owned?']
# ['What is the average per capita share for water supply in Nigeria?']
# ['How many schools have access to basic sanitation services?']
# ['How many schools have basic water and hygiene services?']
# ['How many health facilities have basic sanitation services?']
# ['How many health facilities have access to basic sanitation and hygiene services?']
# ['How many diarrhoea cases per month are reported in the past 12 months']
# ['How many markets and motor parks have access to basic sanitation services?']
# ['How much did households spend in 2021 for WASH?']
# ['How much was spent on water supply services in 2021?']
# ['How much was spent on sanitation services in 2021?']
# ["What is the main goal of Nigeria's WASH services?"]
# ['What is the d ata presented on the d ata?']
# ['What is the purpose of water utilities to do to improve the quality of their utilit ies']
# ['What is the need for the expansion of the scope of sanitation service delivery across all levels in the']
# ['What is the main reason for the pandemic?']
# ['What is the main reason for the increase in water prices?']
# ['What is the primary goal of achieving SDGs 6.1 and 6.2 by 2030?']
# ['What is the need for deep dive into the data to concludeively concludesively conclude that the']
# ['What can be useful in a review of current WASH policies, strategies, and interventions?']
# ['What is the WASH Fund and WASH sector Revitalization Plan?']
# ['What is the name of the water that is a sanitation system?']
# ['What is the National Outcome Routi?']
# ['What is the Summary of the 2021 Mapping Summary of the 2021 Mapping Summary of']
# ['What is the Federal MYS?']
# ['What is the inistry of Water Resources?']
# ['What is the main challenge in Nigeria?']
# ['What is the third in the series of national assessments of WASH Services launched in 2018?']
# ['What is the name of the NGO that funded the 2021 WASH NORM?']
# ['What was the overall leadership of the Federal Ministry of Water Resources?']
# ['What is the average per capita volume of water for rural population?']
# ['What is the name of the main water, sanitation, and hygiene services that Poor Middle Rich Rich']
# ['What is the name of the group that provides WASH Services by Household Head?']
# ['What is the overall status of the WASH Sector in Nigeria?']
# ['What is the most significant disparity related to wealth?']
# ['What is the average income for households with poor households?']
# ['What is the name of the area value map of Nigeria showing access to basic WASH services across']
# ['How many people were accessing basic WASH services in 2018?']
# ['How many people gained access to basic WASH services between 2019 and 2021?']
# ['What percentage of the population in 2018 was a WASH service?']
# ['How many people with access 18 million people with access 20 million people with access?']
# ['How many water, water, sanitation, Hygiene National Outcome Routine Mapping']
# ['What is the name of the Nigerians access to basic water, sanitation and hygiene services?']
# ['What percentage of Nigerians ACCESS to BASIC WATER SUPPLY and BA']
# ['What is the name of the Rural Urban National Rural Urban Nat?']
# ['What percentage of the population is poorest poor middle rich richest?']
# ['How many Nigerians have access to basic drinking water supplanting?']
# ['What is the decline in access to basic water supply services amongst the richest household?']
# ['What percentage of people in rural areas have less access than people in urban areas?']
# ['What is the average age of Household Head?']
# ['What is the name of the national access to basic drinking water supply services?']
# ['How many years did the National Urban Rural Surface Mapping take place?']
# ['What is the average person in Lagos who uses basic water supply?']
# ['What is the name of the Safely Managed Services?']
# ['What is the maximum collection time for a round trip?']
# ['What is the water source from a river, dam, lake, pond, stream,']
# ['What is the name of the water supply system in Nigeria?']
# ['How many states are water utilities classified as functional?']
# ['How many water points are constructed in Nigeria?']
# ['How many states have caretakers in place?']
# ['How many taps are fed by urban utilities?']
# ['What is the name of the main purpose of the water, Sanitation, Hygiene']
# ['How many public water points are functional in Nigeria?']
# ['How many water points are dependable in Nigeria?']
# ['What percentage of public water points are functional?']
# ['What is the Functionality of All Facilities by Ownership?']
# ['What is the average per capita share of dr in rural areas?']
# ['How much water does the population use in rural areas?']
# ['What is the term for “Stressed” water facilities?']
# ['What is the per capita share of water facilities?']
# ['What is the per capita share of water in Nigeria?']
# ['What is the water source point of consumption low?']
# ['What is the name of the l) High?']
# ['What percentage of drinking water at source and point of consumption within Nigeria is contaminated with E.']
# ['How much of all improved drinking water sources are contaminated?']
# ['What is the result of evaluating water based on?']
# ['How many water, sanitation, Hygiene National Outcome Routine Mapping 2021']
# ['How many Peri-Urban Urban Centers Itenerant Core Rural Areas']
# ["What is the name of Nigeria's population that has access to basic sanitation services?"]
# ['What is the average percentage of rural : Ur']
# ['What is the ban on access to basic sanitation services?']
# ['How many water, sanitation, Hygiene National Outcome Routine Mapping 2021']
# ['What is the Equity in Access to Sanitation Services Open Defecation by Geo']
# ['What is the name of the school that provides access to Sanitation Services by Household Head']
# ['What is the name of the school that s with Persons Living with Disabilities Open']
# ['What is the pen Defecation by Gender of Head of Household Access to']
# ['How many years ago did the Water, Sanitation, Hygiene National Outcome']
# ['What is the name of the Sanitation Service in Niton?']
# ['What is the name of the Safely Managed Services?']
# ['What is improved facilities shared by two households?']
# ['What is open Defecation?']
# ['What is the name of the 2021% National Urban Rural?']
# ['What percentage of household members have access to basic hygiene services?']
# ['What is the percentage of access to Basic Hygiene Services by Wealth Quintiles?']
# ['What is the main reason for handwashing?']
# ['What is the name of the area that provides basic hygiene services?']
# ['How many water, sanitation, Hygiene National Outcome Routine Mapping 2021']
# ['What river is the river delta of Nigeria?']
# ['What is the area value map for access to basic hygiene services in Nigeria?']
# ['What is the name of the Hygiene Services by State Hygiene Service Ladder']
# ['What is the name of the area where there is no handwashing facility on premises?']
# ['How many schools have basic water supply, sanitation, and hygiene services?']
# ['What percentage of schools in rural areas have access to water and sanitation services?']
# ['What are schools with useassainment and hygiene services?']
# ['What is the main toilet/latrines available during school days?']
# ['What percentage of Rural Urban National ACCESS to BASIC WATER SUPPLY AND BA']
# ['How many water, water, sanitation, Hygiene National Outcome Routine Mapping']
# ['What is the name of the school that has access to basic water supply, sanitation, and hygiene']
# ['What type of schools have more access than primary schools?']
# ['What is the basic sanitation services in schools?']
# ['What is the name of the school that has girls’ toilet compartments?']
# ['What percentage of health care facilities have basic water supply, sanitation, and hygiene services?']
# ['What are the health care facilities in rural areas more disadvantaged in access to?']
# ['What is the primary facilities?']
# ['How many household members have diarrhoea in the past 2 weeks preceding']
# ['What percentage of rural rural rural rural SE have access to basic water supply sanitation and hygiene services?']
# ['How many water, sanitation, and Hygiene services are available in Health Facilities?']
# ['How many health facilities in Nigeria have basic water supply services?']
# ['What is the name of the health facilitation system that provides WASH in Health Care Facilities?']
# ['What is the basic sanitation service?']
# ['How many labelled bins are separated in the consultation areas?']
# ['How many markets and motor parks have basic water supply, sanitation, and services?']
# ['What is the name of the most common areas in Nigeria?']
# ['What percentage of Markets/Motor Parks have basic water supply services?']
# ['What is the basic hygiene services 8% Markets/Motor Parks have basic']
# ['What is the name of the latrines that are cleaned once a day?']
# ['What is the water supply of the Hygiene National Outcome Routine Mapping 20']
# ['What is the cost of toilet maintenance?']
# ['What was the amount of money spent on WASH Households in Nigeria?']
# ['What is the estimated amount of water, sanitation, and hygiene services in 2019 and 2020?']
# ['How much is the average cost per person?']
# ['Back to the back of the page']
# ['What is the groun groun?']
# ['d and']
# ['What is the Intranet Intranet Intranet Intranet Intranet Intr']
# ['What is the oduction of oduction?']
# ['What is the main human right?']
# ['What is the acceptable standard of access to adequate WASH services?']
# ['What is the main cause of the absence of WASH services?']
# ['What can result in fatalities from preventable diseases amongst the poore st']
# ['What is the name of the nitrates that are present in the water supply?']
# ['What is the only problem with the limited access to comprehensive WASH services?']
# ['What is the name of the mash-ups that are at increased risk of infection']
# ['What is the overall outlook of WASH sector indices still below the desired progress towards the']
# ['How many Nigerians defecate in the open?']
# ['How many families consume f aecal-contaminated drinking water at home?']
# ['What is the main reason for the failure of water systems in Nigeria?']
# ['How many public water systems do not have?']
# ['What percentage of diarrhoea deaths are in low and middle income countries?']
# ['What is the WASH sector 1.1.3.1?']
# ["What is the main focus of Nigeria's WASH sector?"]
# ['What is the main reason for the WAS s?']
# ["What is Nigeria's Visioning and Strategies to Achieve the SDGs?"]
# ['What is the National Open Defe cation Free Roadmap?']
# ['What is the name of the National ODF campaign?']
# ['What is the WASH Information Management System?']
# ['What is the commitment to achieve sustainable WASH exhibited at the highest level of government?']
# ["What is Nigeria's commitment to WASH?"]
# ['How much of the GDP is needed from the public sector?']
# ['How much of the GDP was invested in the sector between 2006 and 2010?']
# ['What is the current WASH budget?']
# ['What is the name of the National Outcome Routine Mapping of WASH services level']
# ['What is the name of the national household- and facility-based survey?']
# ['What is the first of its kind?']
# ['What is the name of the first WASHNORM survey conducted in 2018?']
# ['What was the most comprehensive and wide-ranging WASH survey ever implemented in Nigeria?']
# ['What is the name of the main focus of the WASH NORM?']
# ['What was the purpose of the WASHNORM survey tools?']
# ['What was the separation of the listing process from the data collection phase in urban utilities mapping?']
# ['What is the WASHNORM 2021 survey?']
# ['What are the objectives of the WASH NORM 2019?']
# ['What is the basis for developing state-wide WASH investment plans?']
# ['What was the main focus of the WASHNORM 2021?']
# ['What was the name of the team that worked on WASHNORM 2021?']
# ['What is the overall lead for the development, resource mobilization and institutionalization of this system?']
# ['What is the name of the committee that was formed to provide input on the survey design, implementation']
# ['What is the name of the NBS responsible for generating socio-economic statistics on all dimensions']
# ['What was the purpose of the WASHNORM mechanism?']
# ['What is the WASHNORM 2021 Report?']
# ['What is the final chapter of the WASHNORM findings?']
# ['What is the demographic and socio-economic characteristics of households in the country?']
# ['What is the overall status of the services households use to access quality drinking water in the household?']
# ['What is the focus of WASH services at household and communiq?']
# ['What is the status of water supply sources and quality o f water services in Nigeria?']
# ['What is the WASH Account module?']
# ['What is the main body of the report?']
# ['What was Met']
# ['hodi']
# ['What is the cal']
# ['What is the name of the Appr']
# ['What is the name of the oach?']
# ['What is the WASHNORM survey?']
# ['What is the name of the WASHNORM 2021?']
# ['What is the name of the WASHNORM household module?']
# ['What was the frame of the NISH constructed from?']
# ['How many EAs were randomly selected from 20 independent replicates?']
# ['How many EAs were covered in the 2021 Methodical Approach district?']
# ['What is the purpose of listing an accurate and nationally representative list of households and water facilities?']
# ['How many EAs were covered nationally?']
# ['What is the name of the building?']
# ['What was the name of the water points listed in the WASHNORM 2021?']
# ['What is the name of the water points listed by geopolitical zones?']
# ['What was the training of trainers at the NBS headquarters?']
# ['How many households were canvassed in each of the 34 states and FCT?']
# ['How many households were selected from the 24,600 households?']
# ['What was the next stage of sampling?']
# ['What is the most knowledgeable about the health and WASH of the household?']
# ['What was the population size of primary and secondary schools?']
# ['What was the average number of schools listed and mapped in each state?']
# ['How many health facilities were sampled across the country?']
# ['How many health facilities were listed and mapped in each state?']
# ['What was the sampling frame for markets a nd motor parks developed?']
# ['What was the name of the survey of urban water utilities?']
# ['How many households were selected from the consumer satisfaction survey?']
# ['What is the total sample estimated to be covered?']
# ['How many WASH in Health Facilities?']
# ['What is the WASH WASHNORM 2021 methodical approach?']
# ['What was the name of the survey that included key measures adapted from?']
# ['What was the MICS survey?']
# ['What was the purpose of the questionnaire?']
# ['What is the name of the module that compares the NORM 2021 modules?']
# ['What is the name of the water supply facility?']
# ['What isfaction rating, Redress mechanism Water quality testing 3 Water point questionnaire General characteristics/']
# ['What is the name of the Sanitary inspection 4 Health, Facilities, Questionnaire General facility']
# ['What is the name of the facility information?']
# ['What is the name of the water supply 6 Public places questionnaire?']
# ['What is the total number of parameters covered per module S/N Survey Modules?']
# ['What was the primary language of the state?']
# ['What was the sa ting exercise used for the main survey?']
# ['How many households were selected in each EA?']
# ['What was the pre-test data collected?']
# ['What was the CAPI device used to create data capturing templates of each questionnaire?']
# ['What was the purpose of the testing of the data collection?']
# ['What was the name of the pilot test?']
# ['How many households were selected and assessed across the two selected states?']
# ['What was the first level training?']
# ['What was the name of the data capture templates?']
# ['What was the main survey instrument?']
# ['What was the first exercise of the survey?']
# ['What was the name of the two-level training method used for the pilot test?']
# ['How many trainers were involved in the ToT?']
# ['How many supervisors were trained for the step down training?']
# ['What was the focus of the training on?']
# ["What was the purpose of the Enumerators' Instructions Manual?"]
# ['What was the purpose of the data capture process?']
# ['What was the name of the NBS State coordinators sent to the Chairmen of sensitive local']
# ['How many field personnel were involved in the household interview?']
# ['What was the name of the questionnaire used to collect data on all other aspects of the household and']
# ['What is the overall objective of the water quality component of WASHNORM 2021?']
# ['What is the recommended indicator for faecal contamination?']
# ['What was the ability of the method to be aligned to global strategies to assess safely managed']
# ['What was the standard operating procedure developed by UNICEF?']
# ['What was the main focus of the zonal training?']
# ['How many households were collected water samples?']
# ['How many blank tests were carried out nationwide?']
# ['How many households were drinking water consumption points and how many households were drinking water collected?']
# ['How many coordinators, 6 Controllers and 37 state officers were trained?']
# ['What was the name of the trainers that monitored the fieldwork?']
# ['What was the name of the group that was visited for the interview?']
# ['What was the CAPI data collected?']
# ['What was the response rate of the WASHNORM 2021 survey?']
# ['What was the WA for the WA for the WA for the WA for the WA for the WA']
# ['What is the SHNORM 2021 survey subject to?']
# ['What is the margin of sampling error for the entire survey?']
# ['What was the sample size of the NORM sampling methodology?']
# ['What is the state level of water?']
# ['What is the name of the Supra Supra Supra Supra Supra Supra Su']
# ['What is the rve of rve?']
# ['y F']
# ['Indd']
# ['What is the name of the ings of the ings?']
# ['How many people are in Nigeria?']
# ['How many households are in rural areas?']
# ['What is the lin kage between access to comprehensive range of WASH services and']
# ["What is the main cause of household members' health problems?"]
# ['What is the average household size in Nigeria?']
# ['What percentage of households are headed by women?']
# ['What percentage of female-headed households are in the Southeast and in the Southwest?']
# ['How many children are under 5 years?']
# ['What is the age distribution of household members?']
# ['What is the WASH service?']
# ['What is the WHO framework for International Classifications of Functioning, Disabi lity']
# ['How many people are living with disabilities?']
# ['What is the key criter for achieving the SDGs?']
# ['What is the most disadvantaged person in rural areas?']
# ['How many households are in the core rural areas?']
# ['What is the primary indicator of the ho usehold?']
# ['What percentage of households are headed by non-literate individuals?']
# ['What is the percentage of literate household heads in the south?']
# ['What is the average net worth of households within a defined geographic area?']
# ['What is the need for wealth index parameter s critical for implementing WASH intervention?']
# ['What is the name of the household wealth index?']
# ['What is the cumulative index of household wealth category generated?']
# ['What percentage of Nigerians are in the richest wealth quintiles?']
# ['How many households live in urban areas are from the richest wealth quintile?']
# ['What percentage of households are in the poorest wealth quintile?']
# ['What is the distribution of households by wealth quintiles across geopolitical zones?']
# ['What is the second leading cause of death in children under five years old?']
# ['What is the relationship between poor wealth index and access to improved WASH services?']
# ['How many households reported suffering from diarrhoea in the past two weeks?']
# ['What is the name of the group of population that is vulnerable to diarrhoe']
# ['What was the most common problem in the population?']
# ['What was the most prevalence of diarrhoea?']
# ['What percentage of households are male-headed?']
# ['What percentage of people in the southern zones are diarrhoea?']
# ['What is the map of Nigeria showing diarrhoea incidence across Nigeria?']
# ['How many Nigerians have access to water supply services?']
# ['How much water is contaminated at the point of consumption?']
# ['What is the name of the UN resolution 64/292 of which Nigeria is a signatory']
# ['What is the key role of WASH in efforts towards the attainment of the SDG']
# ['What is the %age of the population using safe managed drinking water free from microbiological']
# ['What is the data collected from the household?']
# ['What is the purpose of the SDG 6.1?']
# ['What is an improved water source?']
# ['What is the water service ladder?']
# ['What is the name of the water that is a better source of water?']
# ['What percentage of the population use improved drinking water supply services?']
# ['How many people in urban areas have access to improved drinking wa ter services?']
# ['What is the main source of drinking water supply in Nigeria?']
# ['What percentage of households use sachet water?']
# ['How many people use pipe-borne water supply sources?']
# ['How many people live in rural areas and 6% of households from the poorest wealth quin']
# ['How many people in the richest quintile are at least 14 times more likely to use']
# ['What is the national action plan for Revitalization of the Nita?']
# ['What is the goal of the WASH sector launched in 2018?']
# ['What percentage of Nigerians have access to safely managed water sources?']
# ['What is the highest level of access to drinking water in the Southwest zone?']
# ['What percentage of the richest households have access to safely managed water services?']
# ['What is the name of the basic water supply service?']
# ['What percentage of the population have access to basic water supply services?']
# ['What percentage of rural households have access to basic water supply services?']
# ['What percentage of household members use basic water supply services?']
# ['What percentage of the population use limited drinking water supply?']
# ['What percentage of people living in the Southsouth region use limited water supply services?']
# ['What is the most detrimental of unimproved water sources?']
# ['What is the lowest and most harmful level of service?']
# ['What is the name of the water services that are unimproved water services?']
# ['What percentage of households in the poorest quintile use surface water?']
# ['What are the five categories of drinking water supply services?']
# ['What was the average time to collect water from the source?']
# ['How many round trips per day do households make to the water source to have enough water?']
# ['How many households leave water fetching to girls and boys under 15 years?']
# ['What is the name of the drinking water supply that should be free from?']
# ['What is considered low risk?']
# ['What is the percentage of households ingest contaminated water at the point of consumption within the']
# ['What is the highest in the northern part of the co untry?']
# ['What is the 94 water, Sanitation, Hygiene National Outcome Rou']
# ['What percentage of the population use drinking water supplies?']
# ['What is the point of consumption in the household?']
# ['How much of water has above 1,000 CFU/100ml at source?']
# ['What percentage of uncontaminated drinking water at point of consumption by Area of Residence Rural Urban National?']
# ['What percentage of Nigerians have access to improved drinking water sources?']
# ['What is the average contamination rate in the Northwest?']
# ['What is the average rate of contamination in the South?']
# ['What percentage of Nigerians are contaminated with coliform?']
# ['How many motorized boreholes were contaminated?']
# ['What is the name of the survey that found water quality in 2021?']
# ['What is the name of the water that Nigerians still fetch?']
# ['What is the health risk associated with tr ansporting and storing drinking water in']
# ['What percentage of households collect drinking water with containers without cover?']
# ['How many households adopt any practice to make their water safer for drinking?']
# ['What is the name of the water treatment method used to treat water?']
# ['What is the role of a water facility?']
# ['What percentage of households were not consulted during the siting of the water facility?']
# ['How much of households pay for water collection in rural areas?']
# ['How many households contributed for water facility repairs?']
# ['What is the percentage of household with Tarrif system for water collection by area?']
# ['What percentage of households are satisfied with water supply services?']
# ['How many households are satisfied with the location of the water points used by the household?']
# ['How many satisfied households with water facilities reported in 2018?']
# ['What percentage of household water point facilities broke down in the last 6 months?']
# ['How many people in Nigeria have access to sanitation services?']
# ["How many people do not dispose of children's faeces safely?"]
# ['How many Nigerians have been defecating in the open in the past 4']
# ['What is the real cost of poor sanitation?']
# ['What is the percentage of the population in WASHNORM 2021?']
# ['What is the name of the use of improved sanitation facilities?']
# ['What is the baseline for measuring access to limited, basic and safely managed sanitation services?']
# ['What percentage of the population use improved sanitation facilities?']
# ['What percentage of people who use improved sanitation facilities are not shared with other households?']
# ['What is the name of the improved facilities that include flush flush to piped sewer systems?']
# ['What is the prevalence of structural defects with improved sanitation facilities?']
# ['How many households in Nigeria use flush or pour-flush systems to sewers,']
# ['What percentage of Nigerians with access to improved sanitation facilities use dry pit latrines with']
# ['What is the highest level in the JMP ladder of sanitation service?']
# ['What is the lowest access to safely managed sanitation in the Southwest zone?']
# ['What is the average population of the United States?']
# ['What percentage of the population have access to basic sanitation?']
# ['What is the wealth of households with the poorest household having 19% access?']
# ['What percentage of households merely from households in 2021?']
# ['How many mbers use limited sanitation services shared with other households?']
# ['What percentage of people who have access to improved latrine use limited sanitation services?']
# ['What percentage of the population rely on unimproved sanitation facilities?']
# ['How many Nigerians practice open defecation?']
# ['How many people have increased in 2019?']
# ['What is the highest prevalence of open defecation in Nigeria?']
# ['What is the name of the survey that found the Prevalence of open defec']
# ['What is the classification of sanitation service ladder?']
# ['How many categories were ped into?']
# ['What are disparities in access for each level of services by area of residence?']
# ['What is the average increase in open defecation in the same period?']
# ['What is the sanitation services ladder by residence and wealth quintiles?']
# ['What is the indicator for safety checks if the latrine is safe for children and persons']
# ['What percentage of households feel their toilets have adequate privacy?']
# ['How many households with latrines reported wastewater leakage from the latrine or overflow']
# ['How many people reported that their faecal sludge was emptied']
# ['What is the faeces of children?']
# ['What percentage of households had faeces cc?']
# ['How many animals live in the compound?']
# ['How many households dispose their garbage?']
# ['How many people dump their garbage elsewhere?']
# ['How many households do not have handwashing facilities?']
# ['How many households had soaps observed in their houses?']
# ['How many people lack a handwashing facility?']
# ['What is the primary goal of WASH?']
# ['What is the primary indicator of access to improved hygiene services?']
# ['What is the WHO/UNICEF JMP hygiene services ladder?']
# ['What is the key to the effective practice of hygiene and maintenance of personal hygiene?']
# ['How many households use temporary items for handwashing?']
# ['What is the problem with handwashing with water and soap?']
# ['What is the name of the sink with tap water?']
# ['What is the highest level of hygiene services?']
# ['What is the proportion of the population where handwashing facilities are available on premises with soap and']
# ['What percentage of the population with basic hygiene services is 17%?']
# ['What percentage of the population had access to basic hygiene services in 2019?']
# ['What is the highest access in the country?']
# ['What percentage of the population is in the United States?']
# ['What is the name of the WHO/UNICEF JMP Sanitation Service?']
# ['What is the access distribution across hygiene services levels based on?']
# ['What percentage of the population lost access to hygiene services between 2018 and 2019?']
# ['What is the ladder by residence and wealth quintiles?']
# ['What is the name of the study that assessed handwashing at critical times?']
# ['How many households practice handwashing before eating?']
# ['What was the average age point increase from 2019 NORM?']
# ['How many households in the Norse area showed proper handwashing?']
# ['How many households demonstrated proper handwashing techniques?']
# ['What is the practice of handwashing at critical times indicators measured on handwashing']
# ['What is the name of the household that is available with the home?']
# ['What is the low figure of handwashing?']
# ['What is the need for a enabling environment for hygiene services to be effective and efficiently utilized']
# ['What is the name of the South South East Knowledge of Critical Times South South Demonst']
# ['What is the national outcome of the Water, Sanitation, Hygiene survey?']
# ['What percentage of the population now have access to basic WASH servic es?']
# ['How many people have gained access to all of the WASH services between 2019 and 2021?']
# ['What is the primary water supply service for households with access to WASH services?']
# ['What percentage of households have basic sanitation services?']
# ['How many waterworks are connected to urban water utilities across Nigeria?']
# ['How many urban water service connections are active?']
# ['How many taps are fed by urban water utilities?']
# ['What is the status of urban water utilities in Nigeria?']
# ['How many states have urban water utilities that produce water?']
# ['How many waterworks were assessed in 2021?']
# ["How much of Nigeria's waterworks capacity is not being used?"]
# ['What percentage of waterworks are partially functional?']
# ['What is the prescribed service standard?']
# ['What is the source of concerns about the integrity of the transmission lines and transformers supplying power']
# ['What was the biggest fa of water, Sanitation, Hygiene National Out']
# ['What is the current capacity utilization of waterworks in Nigeria?']
# ['What is the name of the waterworks located in Nigeria?']
# ['What is the primary source of power?']
# ['How many Crash Programme Boreholes Enugus?']
# ['What is the name of the waterworks location?']
# ['What is the name of the waterworks location?']
# ['How many National Grid/Generator 3 Kaduna North Kaduna 2']
# ['What was the name of the waterworks mapping in Selected Settlements and Study Limitation?']
# ['What is the name of the plant serving the settlement?']
# ['What was the study of the selected waterworks?']
# ['What is the main source of supply?']
# ['What is the main corridor of the water that is leaking along pipelines?']
# ['What is the average inadequate &/aged infrastr?']
# ['What percentage of Low Operational Efficiency is 0% 0% 0% 0% 0%']
# ['What is the average water resource in NC SW SS SE?']
# ['What is the name of the WASHNOR service?']
# ['What is the name of the public water utilities that is located within the household premises?']
# ['How many people are connected to urban water utilities services?']
# ['What percentage of households do not always consume tap water for drinking?']
# ['What is the reason for not drinking from taps connected to urban water utilities?']
# ['How many taps are fed by urban water?']
# ['What is the average coliform forming unit per 100ml?']
# ['What is the regional trend of cynicism?']
# ['What is the average monthly tariff across the nation?']
# ['What is the average monthly flat rate per Connection?']
# ['What was the average satisfaction level of water utilities consumers were asked to rate?']
# ['What was the most highly rated service they will like?']
# ['How many households indicated they were either indifferent or dissatisfied with the duration of']
# ['How many lds were not satisfied with the process of reconnection when they are']
# ['What is the number of water utilities services in the 2021 survey?']
# ['How many years did the process of obtaining a new cc begin?']
# ['What process of reconnection is disconnected when disconnected?']
# ['What is the name of the method of billing?']
# ['What is the name of the complaint that I received from the complaint?']
# ['How many water points are located in Nigeria?']
# ['How many water points are there for people living with disabilities?']
# ['How many water points are provided by donors?']
# ['How much water is per person per day in Nigeria?']
# ['What is the key aspect that is tracked?']
# ['How many water points does the survey estimate in Nigeria?']
# ['What percentage of motorized boreholes are solar powered?']
# ['What percentage of community water points are provided by individual, communities, private businesses?']
# ['How many water points are publicly -used?']
# ['What percentage of water point caretakers are females?']
# ['What is the most likely to be tethered, teeter,']
# ['What is the premise on which the WASH NORM interrogate water quality?']
# ['What is the physical quality of water?']
# ['What percentage of water sources are not adequately protected from fecal contamination?']
# ['What is the name of the water facility located within 30 meters of the water point?']
# ['How many water points were documented during the 2021 WASHNORM survey?']
# ['What is the name of the area that has more breakdowns than other areas?']
# ['What percentage of privately-owned water points are privately owned?']
# ['What is a measure of reliance on or likelihood of performance of a water supply system']
# ['What is the tem used to measure how reliable a system is to deliver quality services?']
# ['What is the WASH NORM?']
# ['What was the minimum benchmark score for measuring the performance of each water facility?']
# ['What was considered non - compliant or not reliable?']
# ['What is the water point that determines if water dries up at specific times of']
# ['What is the s iting, structure and quality of water from the water points?']
# ["What is the metric of water systems's Parameter Indicator Weight Variable Weight"]
# ['What percentage of water does water dry up?']
# ['What is the weight distributed to the first 2 parameter?']
# ["What percentage of Nigeria's water point in the Southwest zone are dependable for design and configuration"]
# ['What percentage of urban water points were indicated to have good design and configuration?']
# ['What is the name of the public private figure 40?']
# ['What is the gender ratio of membership of the WASHCOM?']
# ['What is the average length of time water is available from the water point in a day?']
# ['What is the name of the tariff system?']
# ['What is the average NZ rating in the Northcentral?']
# ['What is the metric for dependability of systems?']
# ['What is the Gender Balance Ratio M/F =1.5 1.5']
# ['What is the ratio of M/F score% 100 75 25 0 0 10% Who']
# ['What is the average daily hours in last 2 weeks when water is available?']
# ['What is the score% 100 0 0 Tariff System?']
# ['What is the Functii system?']
# ['What is the waterpoint that is functional?']
# ['What percentage of privately owned water facilities were assessed to be more functional than public water facilities?']
# ['What percentage of public water facilities are public water facilities?']
# ['What percentage of rural water points had better functionality result?']
# ['What is the name of the public private table?']
# ['What is the weights option score?']
# ['How long did facility function before 1st breakdown?']
# ['What is the average percentage of water facilities?']
# ['What percentage of rural areas were covered in the NORM Rural survey?']
# ['What is the standard number of persons served by each category of water point?']
# ['How many people were within 500 m of each water point?']
# ['What is the percentage of water obtainable from each facility?']
# ['What is the average population in each polygon divided by?']
# ['What is the average per capita share of water in Nigeria?']
# ['What is the national North Central North East North West South East South South Soua?']
# ['What is the average per capita per capita?']
# ['What was the percentage of water supply in Nigeria?']
# ['What is the name of the system that is not contributing to PCS?']
# ['What is the population of the system that serves about twice as much as they should serve?']
# ['What is the PCS prescribed by National Standards for Rural Are as?']
# ['What is the percentage of water facilities that meet the PCS of 15 L?']
# ['What percentage of water points were less adequate than public owned water points?']
# ['What was the average increase in stress in 2018?']
# ['What is the distribution of the population by adequacy categories?']
# ['What is the main reason schools in urban areas have basic water supply services?']
# ['How many rvices are there in schools in urban areas?']
# ['How many schools have on-budget funds for maintenance of WASH facilities?']
# ['What is the importance of access to WASH services?']
# ['What is the name of the Corona Virus?']
# ['What is the main reason for the lack of water facilities?']
# ['What is the WASH NORM survey?']
# ['What is the name of the school that provides drinking water from an improved source and water?']
# ['What is the name of the school that has water and soap available at the time of the survey']
# ['What is a sink with tap water?']
# ['How many schools are fenced?']
# ['How many schools have improved water supply facilities?']
# ['What percentage of students are people?']
# ['What percentage of schools have improved water supply facilities within the premises that is accessible to pupils/stud']
# ['What is the percentage of schools with basic water supply services in rural areas?']
# ['How many schools have limited access to water supply services?']
# ['What is the current access to water supply services in schools according to?']
# ['What is the percentage of schools with access to advanced basic water supply services?']
# ['What is the proportion of schools with toilets or latrines?']
# ['How many schools have improved toilets within the school buildings?']
# ['What percentage of schools use flush toilets?']
# ['How many schools have separate blocks of improved toilets for males and females?']
# ['What is the percentage of schools with latrines have at least one compartment that is accessible to']
# ['What percentage of schools in rural areas are access to basic sanitation services?']
# ['What percentage of schools have unimproved sanitation facilities?']
# ['What is the current access to sanitation services in schools according to the categories of the WHO/UN']
# ['What is the difference between access and access to toilets?']
# ['What is the status of hygiene services in schools?']
# ['How many schools have access to basic hygiene services?']
# ['What is the status of hygiene services?']
# ['What is the average age of primary secondary secondary?']
# ['What percentage of schools in the southern region have access to basic hygiene services?']
# ['What percentage of schools have no hygiene services?']
# ['What is the percentage of schools with access to WASH Facilities in schools?']
# ['What percentage of schools with improved water sources and sanitation facilities at the school are single-sex']
# ['What is the primary secondary school in the UK?']
# ['What percentage of schools have basic gender-sensitive WASH services?']
# ['What percentage of schools with improved water sources and improved sanitation facilities are single -sex with']
# ['What is the percentage of secondary schools in urban and rural areas?']
# ['What percentage of rural urban nationals are in rural schools?']
# ['What percentage of health facilities have basic water supply services?']
# ['What percentage of hospitals do not have toilets/latrines on premises Flush/p']
# ['How many health facilities have improved toilets?']
# ['How many toilets are available to staff and patients?']
# ['What is the BASH service that provides health care?']
# ['How many HFCs does the HCF have?']
# ['What percentage of neonatal deaths are caused by unclean births?']
# ['What is the importance of WASH in HCFs?']
# ['What is the name of the survey that identifies the status of WASH services in healthcare']
# ['What is the safe and hygienic way to dispose of infectious waste?']
# ['What is the water available from?']
# ['What is the minimum water within 500 metres of the facility?']
# ['What is the water taken from?']
# ['How many HFs with WASH facilities keep dedicated budget for cleaning and maintaining?']
# ['How many health facilities have access to improved water supply facilities?']
# ['What is the primary secondary secondary PLWD?']
# ['What is the average age point increase in water supply services in health facilities?']
# ['What is access to basic water supply services in urban health facilities?']
# ['What percentage of health facilities have limited access to water supply services?']
# ['What was found to be the current access to water supply services in health facilities?']
# ['What is the water supply services ladder in health facilities?']
# ['How many health facilities use pit latrines with slabs?']
# ['How many health facilities have improved toilets?']
# ['What is the most common geopolymic of health facilities?']
# ['What is the lowest access in itical zones?']
# ['What is the primary secondary figure 59?']
# ['What percentage of all health facilities have unimproved toilets?']
# ['What is the WHO/UNICEF JMP ladder?']
# ['What is the main component of accessibility for patients?']
# ['What is the name of the service available for both staff and 11% of the staff?']
# ['How many health facilities have hand hygiene stations with soap and water at points of care?']
# ['What is the percentage of health facilities where garbage and wa ste are safely separated into?']
# ['What is the minimum amount of water in handwashing facilities in health facilities?']
# ['What is the lowest access level in rural health facilities?']
# ['What percentage of health facilities did not have functional handwashing facilities at the points of care or']
# ['What is the percentage of health facilities with access to basic WASH services s s']
# ['What percentage of tands are in health facilities?']
# ['What is the main feature of handwashing facility?']
# ['What is the main toilet available at the health facilities?']
# ['What is the name of the basic WASH services in health facilities?']
# ['What is the main reason for access to WASH services in public places?']
# ['How many ks in urban areas is in urban areas?']
# ['How many markets and motor parks have access to basic hygiene services?']
# ['What is a key factor in the prevention and con tainment of diseases that']
# ["What is the WASHNORM's standardized indicato rs?"]
# ['What is the water, sanitation, and Hygiene National Outcome Routine Mapping']
# ['What is the name of the public place that is not single-sex?']
# ['What is the name of the unimproved facilities?']
# ['What is the name of the sink with tap water?']
# ['What percentage of motor parks have improved water supply facilities?']
# ['What is the most reliable and regular availability of water supply in markets and motor parks?']
# ['What is the average water supply service available throughout the year?']
# ['What percentage of markets and motor parks have limited access to water supply services?']
# ['What is an improvement in access from 2019?']
# ['What is the current access to water supply services in markets and motor parks according to the categories of']
# ['What was the water supply services ladder for markets and motor parks?']
# ['What is the predominant latrine type in publi c places that have toilets?']
# ['How many markets and motor parks have improved and useable toilets within the premises?']
# ['How many markets and motor parks provide improved toilets?']
# ['What is the main purpose of the facility?']
# ['What percentage of markets and motor parks have access to basic sanitation services?']
# ['How many people are in urban areas?']
# ['What is the proportion of markets and mops?']
# ['What percentage of tor parks have unimproved sanitation services?']
# ['What is the name of the advance ladder by area of residence?']
# ['How many of the public places have handwashing facilities by toilet blocks?']
# ['What percentage of markets and motor parks have accacces?']
# ['What is the main area of residence where handwashing facilities were available by the toilet?']
# ['What percentage of markets and motor parks have limited hygiene services?']
# ['What percentage of people do not have handwashing facilities within their public place?']
# ['What is the 158 Water, Sanitation, Hygiene National Outcome Rou']
# ['What is the proportion of markets and motor parks with access to basic water supply and sanitation services?']
# ['What percentage of the toilet/latrines available at the time of the survey is used?']
# ['What percentage of rural areas recorded a recorded ording 20 %?']
# ['What is the worst hit in public places?']
# ['How much did the per capita expenditure by households in 2020 be?']
# ['How much was spent on sanitation services by households in 2020?']
# ['What is the estimated amount of ng in 2020?']
# ['What is the need for reliable data on household expenditures?']
# ['What is the exchange rate used for the out of pocket expenditure on WASH?']
# ['How many households were assessed for the WASH accounts?']
# ['What is the total expenditure on WASH?']
# ['How much did Nigeria spend on WASH in 2020?']
# ['What was the average household in the richest wealth quintile in 2018?']
# ['How much does the WASH expenditure go to?']
# ['How much was spent per household in 2020?']
# ['What percentage of household WASH expenditure was in 2020?']
# ['How much did the average spend per household be?']
# ['What percentage of non capital expenditure is 84 %?']
# ['What is the name of the toilet cleaning system that is used for toilet use?']
# ['What was the highest expenditure in 2021?']
# ['How much was spent on transportation from water source?']
# ['How much was the least expenditure on the bills/levies?']
# ['How much money did male headed households spend in the wealth quintile?']
# ['How much was spent in households without people living with disability?']
# ['How much money did households spend on sanitation services in 2020?']
# ['What percentage of household sanitation expenditure was on construction?']
# ['How much was spent by the richest households?']
# ['How much did males headed households spend on sanitation services?']
# ['How much did the amount of people living with disabilities spend?']
# ['How much did the estimated expenditure for hygiene services by all 42, 541, 141 sample households']
# ['What percentage of hygiene expenses was on bathing and lundary soup?']
# ['How much of the total hygiene spending was incurred by households in the Southwest?']
# ['What percentage of households spent 990 million in 2020?']
# ['How much did male heaed households spend on hygiene services?']
# ['']
# ['on']
# ['What is the name of the cl']
# ['What is the name of the group that we are able to use to make up our own']
# ['What is the ions that are ions?']
# ['What percentage of Nigerians had access to basic water, sanitation and hygiene service combine?']
# ['What is the main focus of the progress in the SDGs?']
# ['What is the proportion of Nigerians reporting using pipe-borne water?']
# ['What percentage of the population uses water piped into their household premises?']
# ['How long does the average time for collecting water for household whose water source is not located in']
# ['How many people are able to access water supply services by 2030?']
# ['What is the low score of the dependability of functionality indicator?']
# ['What is the responsibility of state water utilities to provide bulk water th rough piped system to']
# ['How many states in Nigeria have fully functional urban water utilities producing water to households?']
# ['How many cubic meters of water is terworks in Nigeria?']
# ['How many households do not depend on water for drinking water?']
# ['What percentage of consumers expressed satisfaction with the quality of the water they accessed?']
# ['What is the need to pursue to improve water production?']
# ['What is the need for the capacity building of the utility agencies in the development of water n']
# ['What is the main reason Nigeria needs to consider implementing the necessary reforms?']
# ['What is a fundamental necessity for sustaining SWAs?']
# ['What is the most typical life-threatening contaminants of drinking water in Nigeria?']
# ['What is the trend of drinking w ater quality status between 2016 and 2021?']
# ['What percentage of the population are contaminated with?']
# ['What is the average thermotolerant coliform forming unit of oli?']
# ['What is the national water safety plan and national drinking water quality management system?']
# ['What is the percentage of the population with access to basic sanitation services moving from 38 % in']
# ['How many LGAs are valid open defecation free?']
# ['How many Nigerians use safe managed sanitation services?']
# ['What is critical focus of the sanitation needs of the vulnerable?']
# ['What was the average age of the household heads in 2021?']
# ['What is the main reason for the lack of awareness among caregivers?']
# ['What percentage of households had a place for hand washing in their dwelling?']
# ['What is the top preventive measures for the spread of infections?']
# ['What is the need for boosting the availability of enabling conditions?']
# ['What is the main reason for the Integrated WASH Programming in Households and Communities']
# ['What is the key to substantially lessening these disease burdens in households and institutions?']
# ['What is the worst affected by the WASH deprivation in rural areas?']
# ['What is the most common type of WASH?']
# ['What percentage of households report that one househo ld member had suffered diarr']
# ['What is the name of the area that has the most disparities in access to WASH services']
# ['What is the most important factor in determining the benefit of a disability?']
# ['How many households were able to use latrines in Nigeria?']
# ["What is the problem with the lack of effective action to boost women's representation at the tables"]
# ['What is the main factor in determining access to WASH services?']
# ['What is the SDG 6.1 and 6.2?']
# ["What is Nigeria's commitment to reduce inequalities among the two domains?"]
# ['What is the need for a national tool or decision-support strategy to guide and inform identification']
# ['What is the most cost-effective and efficient use of resources in Nigeria?']
# ['How many states have functional urban water utilities that are supplying water to households working at average capacity']
# ['What is the gap between private and public facilities?']
# ['What is the eir operation and maintenance system critically low?']
# ['What is the first comprehensive database for the aggregation of household WASH expenditures at']
# ['What is the only purpose of conducting the household WASH expenditure survey?']
# ['What is the s to the total WASH expenditure in the sector?']
# ['What is the main focus of the FMWR strategy?']
# ['What is the main source of financing for WASH services?']
# ['What percentage of households spent N93 billion in expenditures?']
# ['What is the cost of latrine financing?']
# ['What is the main reason for the lack of latrines?']
# ['What is the average expenditure for latrine construction?']
# ['What is the total household WASH expenses for 2021?']
# ['What is the main focus of the GoN?']
# ['What is the benefit of having access to an improved drinking water source?']
# ['What is the name of the WASH?']
# ['What is the name of the document that was released from WASHIMS - Intervention Profil']
# ['What is the name of the toolkit for hygiene advocacy?']
# ['What is the name of the Washington Group on Disability Statistics?']
# ['What is the name of the World Bank group?']
# ['What is the UN-water global analysis and assessment of sanitation and drinking water?']
# ["What is the WHO's estimate of death by Causal Causal Causal"]
# ['What is the name of the WHO?']
# ['What is the global status report 2019?']
# ['What is the WHO/UNICEF JMP Estimates for Household WASH?']
# ['What is the name of the website that is available from www.washdata.org?']
# ['Ta Ta Ta Ta Ta Ta Ta Ta Ta Ta Ta Ta Ta Ta Ta Ta Ta Ta Ta']
# ['What is the name of the bleak bleak bleak bleak']
# ['of']
# ['An An']
# ['What is the alysis of alysis?']
# ['What table is the water supply table?']
# ['What is the consumer satisfaction with Water Serv?']
# ['What is the name of the composites that 304 Education Composites 322 Education Analy']
# ['How many Composites for Public Places are used in public places?']
# ['How many Tables are Analyzed?']
# ['Water, Sanitation, and water, water, water, water, water, water,']
# ['What is the Hygiene National Outcome?']
# ['What is the Routine Mapping of 2021?']
# ['Tables Householdhold alyzed Tables Householdhold Householdhold House']
# ['Tables Household Tables Household Tables']
# ['How many years does HH members with Disability Age Distribution?']
# ['How many people in the South-West are there?']
# ['How many people are there in the rural 5.4 94.6 100?']
# ['How many people are there in the Bayelsa?']
# ['How many Ebonyi 3.5 96.5 100 0.0 4.5 27.3 46.']

# %% [markdown]
# Pickle them so we don't have to regenerate every time

# %%
import pickle

# Save documents as a pickle file
output_path = "all_questions.pkl"
with open(output_path, "wb") as f:
    pickle.dump(all_questions, f)

# %% [markdown]
# Load them back in and write them into a .txt file

# %%
with open('all_questions.pkl', 'rb') as f:
        questions = pickle.load(f)

# %%
import regex as re
output_file = "all_questions.txt"
clean_questions = ''
for question in questions:
    for quest in question:
        clean_questions += str(quest) + '\n'

clean_questions = re.sub(r'[\[\]]','',clean_questions)

with open(output_file,'w') as f:
    f.write(clean_questions)

# %%
output_file = "all_small_dataset_questions.txt"
small_clean_questions = ''
for question in questions[:13]:
    for quest in question:
        small_clean_questions += str(quest) + '\n'

small_clean_questions = re.sub(r'[\[\]]','',small_clean_questions)

with open(output_file,'w') as f:
    f.write(small_clean_questions)

# %% [markdown]
# ### Answer generation part
# Now we generate the answers by running a summarization model on each page divided by 5; using the same parts as the question so, the summary of each part will correspond to the answer of the question.
#
# Actually, the summaries weren't so good so I answered manually by matching up each question with the passage it came from in the report.

# %% [markdown]
# Building a dictionary structure to hold the questions amswers and difficulty

# %%
questions_file = "small_dataset_questions.txt"
answers_file = "small_dataset_answers.txt"

test_data = {}

with open(questions_file, "r") as qf, open(answers_file, "r") as af:
    questions = qf.readlines()
    answers = af.readlines()

for idx, (question, answer_line) in enumerate(zip(questions, answers), start=1):
    question = question.strip()
    answer_line = answer_line.strip()
    question = question[1:-1]

    # Split the answer line into difficulty and answers
    difficulty, answer_text = answer_line.split(",",1)
    difficulty = int(difficulty)
    answer_list = [answer_text[1:-1]]

    # Store in dictionary
    test_data[idx] = {
        "question": question,
        "difficulty": difficulty,
        "answers": answer_list
    }

# Output the dictionary
print(test_data)
# Out:
# {1: {'question': 'What does WASHNORM stand for?', 'difficulty': 2, 'answers': ['WASHNORM stands for Water Sanitation and Hygiene National Outcome Routine Mapping']}, 2: {'question': 'What is the annual WASHNORM survey?', 'difficulty': 1, 'answers': ['The annual WASHNORM survey is an annual national household and facility-based survey encompassing a comprehensive range of key outcome indicators and parameters related to the WASH sector.']}, 3: {'question': 'What changes were made to the scope and methodology of WASHNORM 2019 in WASHNORM 2021?', 'difficulty': 3, 'answers': ["'A few questions on COVID 19 were added to the household module and the public utility mapping was expanded to include the energy requirement of urban waterworks."]}, 4: {'question': 'What are some key objectives of WASHNORM?', 'difficulty': 2, 'answers': ["'To provide up-to-date and detailed data, gain insight from different stakeholders, monitor and track WASH outcomes, strengthen WASH institutions."]}, 5: {'question': 'On what basis are state-wide WASH investment plans developed?', 'difficulty': 2, 'answers': ["'State-wide WASH investment plans are developed on the basis of the data obtained from the WASHNORM report"]}, 6: {'question': 'Where in Nigeria was WASHNORM carried out?', 'difficulty': 1, 'answers': ["'WASHNORM was carried out in all 36 states of Nigeria and the FCT, Abuja."]}, 7: {'question': 'When was data collection conducted?', 'difficulty': 1, 'answers': ["'Data collection was conducted in the third and fourth quarter of 2021?"]}, 8: {'question': 'How many EAs were covered in total, in all 36 states?', 'difficulty': 1, 'answers': ["'A total of 1,640 EAs were covered in all 36 states"]}, 9: {'question': 'How many households were targeted in each state excepting Lagos and Kano?', 'difficulty': 3, 'answers': ["'600 households were targeted in each state excepting Lagos and Kano."]}, 10: {'question': 'How many households were targeted in each of Lagos and Kano?', 'difficulty': 3, 'answers': ["'1,800 households were targeted in each of Lagos and Kano"]}, 11: {'question': 'How many households were targeted in total?', 'difficulty': 3, 'answers': ["'24,600 households were targeted in total"]}, 12: {'question': 'How was the water quality assessment done?', 'difficulty': 2, 'answers': ["'Water quality assessment was done by listing all the water points within an EA, and 8,200 households were selected across the states."]}, 13: {'question': 'Which institutions were included in the sampling frames?', 'difficulty': 2, 'answers': ["'Primary schools, secondary schools, health facilities, urban water utilities, markets and motor parks"]}, 14: {'question': 'How many primary and secondary schools were listed across the country?', 'difficulty': 1, 'answers': ["'2,050 primary and secondary schools were listed across the country."]}, 15: {'question': 'What percent of the targeted samples was data collected from?', 'difficulty': 1, 'answers': ["'Data was collected from 98.6% of the targeted samples."]}, 16: {'question': 'How many households were actually covered in the houshold survey?', 'difficulty': 3, 'answers': ["'22,353 households were covered in total."]}, 17: {'question': 'How many households were actually covered for the water quality assessment?', 'difficulty': 3, 'answers': ["'7,859 households were covered for the water quality assessment."]}, 18: {'question': 'How many facilities were covered for the water quality assessment?', 'difficulty': 3, 'answers': ["'2,761 facilities were covered for the water quality assessment."]}, 19: {'question': 'How many households were covered for the Household WASH Expenditure?', 'difficulty': 3, 'answers': ["'22,353 households were covered for the household WASH expenditure."]}, 20: {'question': 'How many facilities were covered for the water source mapping?', 'difficulty': 3, 'answers': ["'3,587 facilities were covered for the water source mapping"]}, 21: {'question': 'How many schools were covered in WASH for educat ...

# %%
# get in second set of answers
new_answers_file = "second_answers.txt"

with open(new_answers_file, "r") as naf:
    new_answers = naf.readlines()

for idx, answer_line in enumerate(new_answers, start=1):
    
    additional_answers = [ans.strip() for ans in answer_line.strip().split("|")]
    
    # Append new answers to the existing list
    test_data[idx]["answers"].extend(additional_answers)

# Updated dictionary now contains both sets of answers
print(test_data)
# Out:
# {1: {'question': 'What does WASHNORM stand for?', 'difficulty': 2, 'answers': ['WASHNORM stands for Water Sanitation and Hygiene National Outcome Routine Mapping', 'WASHNORM stands for Water, Sanitation, and Hygiene National Outcome Routine Mapping.', 'WASHNORM is an acronym for Water, Sanitation, and Hygiene National Outcome Routine Mapping.', 'The full form of WASHNORM is Water Sanitation and Hygiene National Outcome Routine Mapping.']}, 2: {'question': 'What is the annual WASHNORM survey?', 'difficulty': 1, 'answers': ['The annual WASHNORM survey is an annual national household and facility-based survey encompassing a comprehensive range of key outcome indicators and parameters related to the WASH sector.', 'The annual WASHNORM survey collects data on national households and facilities, covering key WASH sector indicators.', 'WASHNORM is an annual survey that gathers household and facility data to track WASH sector outcomes.', 'Each year, the WASHNORM survey collects a variety of outcome indicators related to the WASH sector from national households and facilities.']}, 3: {'question': 'What changes were made to the scope and methodology of WASHNORM 2019 in WASHNORM 2021?', 'difficulty': 3, 'answers': ["'A few questions on COVID 19 were added to the household module and the public utility mapping was expanded to include the energy requirement of urban waterworks.", 'The 2021 WASHNORM survey added COVID-19-related questions to the household module and expanded the public utility mapping to include energy needs for urban waterworks.', 'In WASHNORM 2021, new COVID-19 questions were included in the household module, and the mapping of public utilities was expanded to include the energy requirements for urban waterworks.', 'WASHNORM 2021 included questions about COVID-19 in the household module and extended public utility mapping to account for energy requirements in urban waterworks.']}, 4: {'question': 'What are some key objectives of WASHNORM?', 'difficulty': 2, 'answers': ["'To provide up-to-date and detailed data, gain insight from different stakeholders, monitor and track WASH outcomes, strengthen WASH institutions.", 'WASHNORM aims to provide current and detailed data, gather stakeholder insights, monitor WASH outcomes, and strengthen WASH institutions.', 'Key objectives of WASHNORM include delivering accurate data, tracking WASH outcomes, engaging stakeholders, and improving WASH institutions.', 'The primary goals of WASHNORM are to offer up-to-date data, engage with stakeholders, track outcomes, and strengthen WASH institutions.']}, 5: {'question': 'On what basis are state-wide WASH investment plans developed?', 'difficulty': 2, 'answers': ["'State-wide WASH investment plans are developed on the basis of the data obtained from the WASHNORM report", 'State-wide WASH investment plans are formulated based on the data derived from the WASHNORM report.', 'WASHNORM data serves as the foundation for developing state-wide WASH investment plans.', 'The data collected from the WASHNORM report is used to create state-wide WASH investment plans.']}, 6: {'question': 'Where in Nigeria was WASHNORM carried out?', 'difficulty': 1, 'answers': ["'WASHNORM was carried out in all 36 states of Nigeria and the FCT, Abuja.", 'WASHNORM was conducted across all 36 states of Nigeria and the Federal Capital Territory, Abuja.', 'WASHNORM was implemented in all 36 states and the FCT of Nigeria.', 'The survey took place in all 36 Nigerian states and the Federal Capital Territory, Abuja.']}, 7: {'question': 'When was data collection conducted?', 'difficulty': 1, 'answers': ["'Data collection was conducted in the third and fourth quarter of 2021?", 'Data collection took place during the third and fourth quarters of 2021.', 'The data was gathered in the last two quarters of 2021.', 'Data collection occurred in the third and fourth quarters of the year 2021.']}, 8: {'question': 'How many EAs were covered in total, in all 36 states?', 'difficulty': 1, 'an ...

# %%
import pickle
# Save documents as a pickle file
output_path = "test_data.pkl"
with open(output_path, "wb") as f:
    pickle.dump(test_data, f)
